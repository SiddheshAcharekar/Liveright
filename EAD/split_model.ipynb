# %% [markdown]
# # Treating categorical and continuous variables separately.

# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import hamming

# %%
og_sheet = pd.read_excel('find_my_buddy.csv.xlsx', sheet_name='Buddy Sheet')

# %%
og_sheet['Full Name'].drop(522)
# Out:
# 0                          Sachin Haldavanekar
# 1                                Sanket Saurav
# 2                                   Viha Bidre
# 3                              Sougata Dafader
# 4                           Athul Muralidharan
# 5                               Megha Suvarna
# 6                                       Vishnu
# 7                             Srashti Kasliwal
# 8                                  Balakumaran
# 9                                       Pranav
# 10                        Harshil Navin Dhruve
# 11                        Shravan kumar reddy
# 12                                Tejas Harish
# 13                                 Rohan Taori
# 14                                           Z
# 15                              Mrunal Ghanwat
# 16                   Varun Sundar Rabindranath
# 17                          Kaustubh Shivdikar
# 18                              Pratik Devikar
# 19                                Saumil Patel
# 20                          Keerthan Bharadwaj
# 21                                    Sreejith
# 22                             Rushaabh Saliya
# 23                            Srinidhi Shankar
# 24                                 Harsh Sheth
# 25                                 Nipun Midha
# 26                                       Varad
# 27                             Chaitanya Joshi
# 28                               Cyril Mathew
# 29                                    VYOM RAJ
#                         ...
# 492                            Harshad Sathaye
# 493                            Mihir Raichura
# 494                              Manva Pradhan
# 495                             Nikunj Kotecha
# 496                            Akash Tripathi
# 497                            Akshat Karambe
# 498    Shyama Sastha Krishnamoorthy Srinivasan
# 499                         Ashutosh Ghildiyal
# 500                               Ayush Shukla
# 501                               KANDARP VYAS
# 502                      Sai Praneeth Macherla
# 503                               Dhruv Sharma
# 504                             Patel Parth B.
# 505                              Nishita Sikka
# 506                                 Shiv Desai
# 507                                Dhruv Patel
# 508                              Siddhika Alve
# 509                                     Mayank
# 510                                Ajit Manuel
# 511                            Abishek Sampath
# 512                             Vikram Aditya
# 513                   Saran Prasad Ambikapathy
# 514                       Parmeet Singh Saluja
# 515                       Raghavan Renganathan
# 516                        Ananth Kumar Shetty
# 517                        Ankur Bambharoliya
# 518                              Sanket Mathur
# 519                                 Rohit Naik
# 520                           Deepak Chandwani
# 521                                   Nivedita
# Name: Full Name, Length: 522, dtype: object

# %%
meta_data = pd.read_csv('budd_new_22_6_18.csv', index_col= 0)

# %%
meta_data.columns
# Out:
# Index(['gender', 'current_city', 'open_to_other_branch', 'work_ex',
#        'dist_from_uni', 'rent_budget', 'alcohol', 'smoking', 'food_pref',
#        'cul_skills', 'looking_for_roommate', 'MS Biotechnology',
#        'MS Civil Engineering', 'MS Computer Science',
#        'MS Computer Systems Engineering', 'MS Data Science',
#        'MS Electrical and Computer Engineering', 'MS Energy Systems',
#        'MS Engineering Management', 'MS Industrial Engineering',
#        'MS Information Assurance and Cyber Security', 'MS Information Systems',
#        'MS Mechanical Engineering', 'MS Project Management', 'Others',
#        'hall_yes_no', 'max_ppr', 'bhk_1', 'bhk_2', 'bhk_3', 'bhk_4', 'studio'],
#       dtype='object')

# %%
meta_data = meta_data.drop(labels=['looking_for_roommate', 'Others'], axis = 1)

# %%
name_list = list(og_sheet['Full Name'].drop(522))

# %%
name_list
# Out:
# ['Sachin Haldavanekar',
#  'Sanket Saurav',
#  'Viha Bidre',
#  'Sougata Dafader',
#  'Athul Muralidharan',
#  'Megha Suvarna ',
#  'Vishnu',
#  'Srashti Kasliwal',
#  'Balakumaran',
#  'Pranav',
#  'Harshil Navin Dhruve',
#  'Shravan kumar reddy ',
#  'Tejas Harish',
#  'Rohan Taori',
#  'Z',
#  'Mrunal Ghanwat',
#  'Varun Sundar Rabindranath',
#  'Kaustubh Shivdikar',
#  'Pratik Devikar',
#  'Saumil Patel',
#  'Keerthan Bharadwaj',
#  'Sreejith',
#  'Rushaabh Saliya',
#  'Srinidhi Shankar',
#  'Harsh Sheth',
#  'Nipun Midha',
#  'Varad',
#  'Chaitanya Joshi',
#  'Cyril Mathew ',
#  'VYOM RAJ',
#  'Bharathwaj',
#  'Sibendu Dey',
#  'Akshat Shukla',
#  'Pragadeesh Suresh babu',
#  'Samruddhi Pai Kakode',
#  'Gaurav Gandhi',
#  'VENKATA SAI TARUN UPPALA',
#  'Grishma Thakkar',
#  'Abhinn Ankit',
#  'Chirayu Desai',
#  'Abhishek Ahuja',
#  'Ninad Kanetkar',
#  'Prasanna Kumar Challa',
#  'Sagar',
#  'Saurabh',
#  'Aman Mankar',
#  'Anup Srivastava',
#  'ganesh surada',
#  'Naman Bhargava',
#  'Vikas Singh',
#  'Prashant Reddy',
#  'Poojith Shankar Shetty',
#  'Prashant Reddy',
#  'Vipul Sharma',
#  'Aparna',
#  'Nishit Ajmera ',
#  'Sumanth',
#  'Karan Tyagi',
#  'Prashant singh',
#  'Santhosh Eswaran',
#  'Vaibhav Rangarajan',
#  'Elavazhagan Sethuraman',
#  'Amogh Shejwal',
#  'Animesh Mane',
#  'Tanmay Sinha',
#  'Paarth Kotak',
#  'KAVYA PRAKASH ',
#  'Shweta Tatiya',
#  'Akash Yadav',
#  'Vishnu Prasad Maruthi',
#  'Nupur jain',
#  'Urvi Rakesh Maru',
#  'karthik keshava',
#  'Chetan M Jadhav',
#  'Akshat Bhatia ',
#  'Aksh Thakkar',
#  'Alay Mehta ',
#  'Punith Narayanaswamy',
#  'sanchit vilas chavan',
#  'Vijayaballaji ',
#  'SHALABH MITTAL',
#  'Pavithran Ramachandran',
#  'Anubhuti Vyas',
#  'Apurva Avinash Landge ',
#  'Neelambari Verma',
#  'Aanchal shah',
#  'Hiral Vora',
#  'Abhijith Athreya',
#  'Jhalak Gupta',
#  'Kavitha Sivakumar',
#  'Abhidipto Sengupta',
#  'Shlok A Gandhi',
#  'Roshan P Shajan',
#  'Ashwinvignesh Ramesh',
#  'Chirag shivnani',
#  'Shefali Shekhawat',
#  'Rahul tyagi',
#  'Taashi Priya Khurana',
#  'Rajashree Naik',
#  'Anubhav Gupta',
#  'Tanmay Senapati',
#  'Manoj venkatesan',
#  'Darshan jain',
#  'Sai yashasvi reddy',
#  'Pradeepa Gopinath ',
#  'Sameer',
#  'Santhosh Eswaran',
#  'Monica',
#  'Prasad Madhale',
#  'Harshith Gowli Chandrakumar',
#  'Vinyas kaushik',
#  'Ravi Krishnan Iyer',
#  'Pallav Choudhary',
#  'Suyash Narkhede',
#  'Sahil Gandhi',
#  'K. Suwarna',
#  'sarath chandra alli',
#  'Deepak Suryakant Padhi',
#  'Shishir Kurhade',
#  'Ishan Patel',
#  'Soham Sheth',
#  'Jay Doshi ',
#  'Sharayu',
#  'Namrata Ghag',
#  'Soham Sheth',
#  'Rishab',
#  'Tejas Munot',
#  'Rahul Motan',
#  'Dhrumil Sanjay Shah',
#  'Sangeetha Chandrashekar ',
#  'Krrish Mittal',
#  'Kartik Dave',
#  'Jhansi Nair ',
#  'Soumyadeep sinha',
#  'Hardik Shah',
#  'Sanjana Panicker',
#  'Neha',
#  'Vishal Shah',
#  'Aashish Thyagarajan',
#  'Tejas Parab',
#  'Rishi Chopra',
#  'Bhargavi Nilesh Padhya',
#  'keval shah',
#  'Akhilesh Hegde I',
#  'Utkarsha Ganla',
#  'Kousthubh B S',
#  'Vikas Gupta',
#  'Rachna Reddy Melacheruvu',
#  'Suhasini Murali',
#  'Shashwat Shetty',
#  'Akshdeep Rungta',
#  'Varsha Rao',
#  'Vishal surya madhavan ',
#  'Sumedh Kulkarni',
#  'Mansi kulkarni',
#  'Manish Patil',
#  'Anvi Modi',
#  'Ashwini Giri',
#  'Nishchay Shah',
#  'Harita Prakash',
#  'Gaurav Raj Chattarki ',
#  'Deep Mehta ',
#  'Kunal Patil',
#  'Ram Prakash',
#  'Kashif Bagdadi',
#  'Kumar Ritesh Ranjan Sinha ',
#  'Harsh Rajesh Patel',
#  'Harsh Rajesh Patel',
#  'Sanket Kolte',
#  'Mitisha Ganesha Dodderi',
#  'Varun Himmatramka',
#  'Rohan Taori',
#  'Swagath V C',
#  'Vignesh Raghuraman',
#  'Krupashankar Sundararajan ',
#  'Himanshu Saraswat',
#  'Ashish Singhal',
#  'Gaurang Davda',
#  'Venkataramanan BJ',
#  'Pratyaksh Gautam ',
#  'Ashmeet Singh Pahwa',
#  'Murtaza Haji',
#  'Adwait Joshi',
#  'Aatish Shah',
#  'Suyash Narkhede',
#  'Aniruddha K',
#  'Namratha R N',
#  'Sthitapradyna ',
#  'Rahul Zore',
#  'Anuj Kapur',
#  'Abhilash Ajjan',
#  'Karishma Lad',
#  'Aditya Joshi',
#  'Shubhi Sharma',
#  'Dharit',
#  'Jai Soni',
#  'Shiv Desai',
#  'Ronak Shah',
#  'Siddharth Dhar',
#  'Javed Nihaz Z ',
#  'Rahil Shah',
#  'Srikant Swamy',
#  'Karan barai',
#  'Vignesh Murali',
#  'Aditya Masurkar',
#  'Darshan',
#  'Gideon Pinto',
#  'Tushar Gupta',
#  'Jigar Dedhia',
#  'Neel Lele',
#  'Gauri Yadav',
#  'Gauri Prakash Chavan ',
#  'Shantanu Deosthale',
#  'Dharit shah',
#  'Shruti Parpattedar',
#  'Mohit Arya',
#  'Abhishek Gharal',
#  'Divya Priya Emmanuel',
#  'Rahul Sinha',
#  'Harshith Gowli Chandrakumar',
#  'Mayur Tarmale',
#  'Varun V Murthy',
#  'LIKHIT MAHADEVASWAMY',
#  'Reuben Mathew Philip',
#  'Nitin Prince',
#  'Shreyansh Singh',
#  'Pratik Parija',
#  'Mansi Jain',
#  'Amish Garhwal',
#  'Krunal Nanda',
#  'Hasher Hamza',
#  'Aeshna kapoor',
#  'Rishi Nandedkar',
#  'Ayush Gupta',
#  'Nidhi Sarode Pundareeka',
#  'Shardul Wagh',
#  'Anshit Srivastava',
#  'Deekshitha V',
#  'Hardik Jain',
#  'Ankush Deora',
#  'Ivan Roger Victor Fernando',
#  'Amey Dongre',
#  'Shreyanth Reddy',
#  'Ojas Phansekar',
#  'Ajinkya Kunjir',
#  'Bhavik Shah',
#  'Ankita Mhatre',
#  'K Aravind',
#  'Syed Meesam',
#  'Danish Siddiqui',
#  'Pooja Alone',
#  'Meghana',
#  'Viveck Dhanwani',
#  'Vaishnavi Hire',
#  'Vlasios Lampiris',
#  'Suyog Sunil Sathe',
#  'Nikitha gandra',
#  'Hitesh Garani',
#  'Viral D Patel',
#  'Tejas Salian',
#  'Kartikey Dave',
#  'Vyas abhi',
#  'Harshvardhan poddar',
#  'Yash Khopkar',
#  'Bhavika Bagaria ',
#  'Brijesh Hirani',
#  'Sanket Navalakha',
#  'Rishika Sinha',
#  'Nupur Jain',
#  'Vishwambhar',
#  'Neel Patel',
#  'Gaurav Raj Chattarki ',
#  'suyash lokhande',
#  'Anuja Waikar',
#  'Mohit Baser',
#  'Akash Piyush Parikh',
#  'Aditya Modi',
#  'Parth Pandya',
#  'Renuka Koranne',
#  'Anupriya',
#  'Pallavi',
#  'Vikram Ramesh',
#  'Harsh Bansal',
#  'Sakshi Tonwer',
#  'Rohan Naik',
#  'Vignesh Pradeepkumar',
#  'Nityashree V',
#  "Clarence D'Silva",
#  'akash gund',
#  'Prathamesh Tari',
#  'Samkit Kamdar',
#  'Shruti Puthran',
#  'Mohit Ruke',
#  'JIMIT Lakhani',
#  'Manasa Bhimaraya Singhekar',
#  'Vijay R',
#  'Manikantha Dronamraju',
#  'jhalak gupta',
#  'pratik jain',
#  'Amit Ghule',
#  'Sai Praneeth Macherla',
#  'Swaraj Shrikant Oturkar',
#  'Neha Varshney',
#  'Mitul Pala',
#  'Neha Bhagwat',
#  'Shubham Agrawal',
#  'Rutuja Pai',
#  'MOHAMED NADEEM AMEERDEEN',
#  'Asif Jan',
#  'Lavanya Verma',
#  'Rohith Nagabhyrava',
#  'Rishi Raj Dutta',
#  'Shruti Kotian',
#  'Shamik Shashank Gaitonde',
#  'Sandesh Agrawal',
#  'Bhavesh Chouksey',
#  'Ekta Sirwani',
#  'Shweta Oak',
#  'VARUN PASARI',
#  'Sheela Sathyanrayana',
#  'Rahul Ramanand Bhat',
#  'Hitesh verma',
#  'Kaustubh Shinde',
#  'Agrima Saraf ',
#  'Omair Shafi Ahmed',
#  'Rishabh Jain',
#  'Nilank Sharma',
#  'Sreerag Sreenath',
#  'Mitul Shah',
#  'Harshit Gupta',
#  'Nupur Deshpande',
#  'Khilan Munshi',
#  'Harman Preet Singh',
#  'Markala Manvita',
#  'Krishnaswaroop Bykadi',
#  'Ankush',
#  'Tanvi Sharma',
#  'Akhil Dilip Rane',
#  'Vishesh Hemnani',
#  'Nikhil Upadhyaya',
#  'Chaitya Shah',
#  'Anindita Maiti',
#  'Ashutosh Mahala',
#  'Bhushan Mohite',
#  'Romil Rathi ',
#  'Darshil Doshi',
#  'Swapnil Shende',
#  'Sanjith Bangera',
#  'Aditya Kalele',
#  'Luvesh Tekchandani',
#  'Deepshikha Sinha ',
#  'Abhay Potharaju',
#  'Amey Pawar',
#  'Parth Tandel',
#  'Deepshikha Sinha ',
#  'Parshva Shah',
#  'Jackin vora',
#  'Amogh',
#  'Aditya Apte',
#  'Divya Singh',
#  'Lohith Shetty',
#  'Nischal M',
#  'Anupam Maheshwari',
#  'Jay Choksi',
#  'Prajwal Ramesh Parlawar',
#  'Neha Gaikwad',
#  'Sayali Gaikawad',
#  'Aneesh Karwarkar ',
#  'Shubham Barhate',
#  'Bhagyashree A',
#  'Chintan shah',
#  'Chaitanya Joshi',
#  'Harsh Mehta',
#  'Rohan Naik',
#  'Swapnil Thakkar',
#  'Rushin Gandhi',
#  'Aditya Prabhu',
#  'Nirav Patel',
#  'Shyam Padia',
#  'Pratik Gala',
#  'Mustafa Kapadia',
#  'Sameer Desai',
#  'Shubham Rastogi',
#  'Priya Singh',
#  'Bishishta Mukherje',
#  'Arvind Mohan',
#  'Shweta Atul Pathak',
#  'Ruturaj vilas nagare',
#  'Akshay Shetty',
#  'Akash Chitrey ',
#  'Amit Ghule',
#  'Radhika Gathia',
#  'Kaustubh Mathkar',
#  'Aniket Nandanwar',
#  'Ritesh Narayan patil',
#  'Neha Bhangale',
#  'Harsh Sharma',
#  'Jai Kumar Soni',
#  'Dheeraj Shetty',
#  'Pankaj Sahani ',
#  'Lohith',
#  'Dyuti Ananthanarayanan',
#  'urvang gaitonde',
#  'Mayur Tarmale',
#  'Vivin Thomas Wilson',
#  'Aravind U',
#  'Shreyas Krishna',
#  'Shreya Sivakumar',
#  'Shivam Odeka',
#  'Mitul Pala',
#  'Ashutosh Ghildiyal',
#  'Naomi Machado',
#  'Burhan Sadliwala',
#  'Darshit Chanpua',
#  'Preyank Jain',
#  'Kshitij Chopra',
#  'Varun.',
#  'Akshatha Joyis',
#  'Vijay Rajagopalan',
#  'Rohan Patki',
#  'Ashish k',
#  'Abhiruchi Karwa',
#  'Akshay Gujarathi',
#  'Srinithi Ramesh',
#  'Nikhil Badugu',
#  'Abhilash G Kothari',
#  'Delwin John',
#  'Ameya Patankar',
#  'Ruta Lad',
#  'Shweta',
#  'Prathamesh Tari',
#  'Pratik Devikar',
#  'Ruchir Vimawala',
#  'Shivank Rai',
#  'Aishwarya Dilip Gavali',
#  'Ketan Kale ',
#  'Viren k bhatia',
#  'Kumar Baibhav ',
#  'Tarun uppala',
#  'Priya ranjan Panda',
#  'Charchil',
#  'CHINMAY SUNIL JONRAJ',
#  'Gokul A N ',
#  'Aashal Shah',
#  'Garvit Chawla',
#  'Neha Buddhadev ',
#  'Shubham Goski',
#  'Surupa Tushar Chatterjee',
#  'Akshay Halyal',
#  'sumanth tippa',
#  'Snehith T C',
#  'sai siri',
#  'Raghuveer Gowda H',
#  'Sneha Pramanik',
#  'Haripriya Venkatachalapathy',
#  'Ashish Powar',
#  'Aarjav Dutt',
#  'Akshita Sachdeva',
#  'Ashwini Suryavanshi',
#  'Javed Nihaz',
#  'Nupur Dongare',
#  'Nishtha Kaura',
#  'Nikilesh K',
#  'Manoj kumar karru',
#  'Siddhesh Acharekar',
#  'Shantanu Bafna',
#  'Abhinav Yogesh Tiwari',
#  'Gaurav Tripathi',
#  'Prathmesh kale',
#  'varsha srinivas',
#  'Sisir Lunawat',
#  'Jagruthi Thekkada',
#  'Rashmi Kalva',
#  'Harshit',
#  'PRASAD',
#  'Anjali Ashok Shah',
#  'Swapnil Patil ',
#  'Aayushi Maheshwari',
#  'Sachin',
#  'Ranga Chari Vinjamuri',
#  'Pratik',
#  'Visakh Venkitaramanan',
#  'Ankita',
#  'Abhishek Ajay',
#  'Dinesh Maria antony',
#  'Vaibhav Rangarajan',
#  'Abhilash ',
#  'varun adhithya',
#  'Hemanth Senthilkumar',
#  'Pranav walimbe',
#  'Sanjana Suresh',
#  'zz',
#  'Harshad Sathaye',
#  'Mihir Raichura ',
#  'Manva Pradhan',
#  'Nikunj Kotecha',
#  'Akash Tripathi ',
#  'Akshat Karambe ',
#  'Shyama Sastha Krishnamoorthy Srinivasan',
#  'Ashutosh Ghildiyal',
#  'Ayush Shukla',
#  'KANDARP VYAS',
#  'Sai Praneeth Macherla',
#  'Dhruv Sharma',
#  'Patel Parth B.',
#  'Nishita Sikka',
#  'Shiv Desai',
#  'Dhruv Patel',
#  'Siddhika Alve',
#  'Mayank',
#  'Ajit Manuel',
#  'Abishek Sampath',
#  'Vikram Aditya ',
#  'Saran Prasad Ambikapathy',
#  'Parmeet Singh Saluja',
#  'Raghavan Renganathan',
#  'Ananth Kumar Shetty',
#  'Ankur Bambharoliya ',
#  'Sanket Mathur',
#  'Rohit Naik',
#  'Deepak Chandwani',
#  'Nivedita']

# %%
meta_data
# Out:
#      gender  current_city  open_to_other_branch  work_ex  dist_from_uni  \
# 0         0             0                     0     3.50            3.0
# 1         0             1                     0     3.50            3.0
# 2         1             1                     0     1.80            3.0
# 3         0             2                     0     3.50            5.0
# 4         0             3                     0     2.00           10.0
# 5         1             4                     0     2.80            3.0
# 6         0             1                     0     3.00           10.0
# 7         1             0                     0     3.50            5.0
# 8         0             3                     0     0.60            3.0
# 9         0             4                     0     2.50            3.0
# 10        0             0                     0     2.50            1.0
# 11        0             5                     0     0.80           10.0
# 12        0             1                     0     0.00            3.0
# 13        0             6                     0     0.00            5.0
# 14        1             7                     0     5.00            1.0
# 15        1             4                     0     0.00            3.0
# 16        0             3                     0     3.50            5.0
# 17        0             8                     0     1.00            3.0
# 18        0             6                     0     0.00            5.0
# 19        0             9                     0     0.30            3.0
# 20        0             1                     0     0.00            3.0
# 21        0            10                     0     1.80            5.0
# 22        0             0                     0     0.00            5.0
# 20             0      2.0      0      1      1      0       0
# 21             0      2.0      1      1      1      1       0
# 22             0      2.0      1      0      0      0       1
# 23             0      4.0      0      1      1      0       1
# 24             1      4.0      1      1      1      1       1
# 25             0      2.0      1      1      1      0       0
# 26             1      4.0      1      1      1      1       0
# 27             0      2.0      1      1      1      1       0
# 28             0      3.0      1      1      1      1       1
# 29             0      4.0      1      1      1      1       1
# ..           ...      ...    ...    ...    ...    ...     ...
# 492            0      4.0      1      1      0      0       0
# 493            0      2.0      0      1      0      0       0
# 494            0      3.0      1      1      1      0       0
# 495            0      1.0      0      1      1      1       0
# 496            0      1.0      0      1      1      1       0
# 497            0      4.0      1      1      0      0       0
# 498            0      2.0      1      1      0      0       1
# 499            0      1.0      1      0      0      0       0
# 500            0      2.0      1      1      0      0       0
# 501            0      4.0      0      1      0      0       0
# 502            0      2.0      0      1      1      0       0
# 503            0      2.0      0      1      1      0       0
# 504            1      4.0      0      1      0      0       0
# 505            0      3.0      0      1      1      0       1
# 506            0      2.0      1      1      0      0       0
# 507            1      2.0      0      1      0      0       0
# 508            0      4.0      1      1      0      0       0
# 509            1      2.0      0      1      0      0       0
# 510            0      2.0      1      1      1      1       1
# 511            1      2.0      1      1      1      1       1
# 512            0      2.0      1      1      0      0       1
# 513            1      2.0      1      1      1      1       1
# 514            0      2.0      1      1      0      0       0
# 515            0      2.0      1      1      0      0       0
# 516            0      4.0      1      1      1      0       0
# 517            1      4.0      1      1      1      1       1
# 518            0      2.0      1      1      1      1       1
# 519            0      2.0      0      1      1      0       0
# 520            0      3.0      1      1      0      0       0
# 521            0      1.0      1      1      0      0       1
#
# [522 rows x 30 columns]

# %% [markdown]
# ## Test area

# %%
test_person = meta_data.iloc[[65]]    # Paarth Kotak

# %%
test_person
# Out:
#     gender  current_city  open_to_other_branch  work_ex  dist_from_uni  \
# 65       0             0                     0      2.0            3.0
#
#     rent_budget  alcohol  smoking  food_pref  cul_skills   ...    \
# 65          700        0        1          1           0   ...
#
#     MS Information Systems  MS Mechanical Engineering  MS Project Management  \
# 65                       0                          0                      0
#
#     hall_yes_no  max_ppr  bhk_1  bhk_2  bhk_3  bhk_4  studio
# 65            0      4.0      0      1      0      0       0
#
# [1 rows x 30 columns]

# %%
meta_data[meta_data['gender'] == 0].iloc[[57]]
# Out:
#     gender  current_city  open_to_other_branch  work_ex  dist_from_uni  \
# 65       0             0                     0      2.0            3.0
#
#     rent_budget  alcohol  smoking  food_pref  cul_skills   ...    \
# 65          700        0        1          1           0   ...
#
#     MS Information Systems  MS Mechanical Engineering  MS Project Management  \
# 65                       0                          0                      0
#
#     hall_yes_no  max_ppr  bhk_1  bhk_2  bhk_3  bhk_4  studio
# 65            0      4.0      0      1      0      0       0
#
# [1 rows x 30 columns]

# %%
test_p_cont = np.array(get_cont_cat(test_person, 'cont'))

# %%
db_cont = np.array(get_cont_cat(meta_data, 'cont'))

# %%
test_p_cont.shape
# Out:
# (1, 3)

# %%
db_cont.shape
# Out:
# (522, 3)

# %%
test_p_cont
# Out:
# array([[  2.,   3., 700.]])

# %%
euclidean_distances(test_p_cont, db_cont).shape
# Out:
# (1, 522)

# %%
def get_cont_cat(dataframe, var_type):
    '''
    Function to split and return the dataframe by the variable type needed.
    
    I/P:
    'dataframe': whole data as a pandas dataframe
    'var_type': variable type, "cont" or "cat", string
    
    O/P:
    'dataframe': dataframe with only columns of the needed variable type
    '''
    
    
    # Convert any series to dataframe
    if not isinstance(dataframe, pd.DataFrame):
        print('ip is not dataframe')
    cont_cols = ['work_ex', 'dist_from_uni', 'rent_budget']
    
    
    
    if var_type == 'cont':
        return dataframe[cont_cols]
    
    
    
    elif var_type == 'cat':
        return dataframe.drop(labels = cont_cols, axis = 1)
    
    
    
    else: raise ValueError('Variable type should be either "cont" or "cat"')

# %%
def get_cont_dist(person, database, metric):
    
    '''
    Function that returns a distance matrix for continuous features of the data.
    Feature normalization happens in here.
    I/P:
    'person': 1 x 3 numpy array of 1 person
    'database': (total data length) x 3 numpy array
    'metric': distance metric to be used for computation. One of: euclidean.
    
    O/P:
    'distance_matrix': 1 x (total data length) numpy array of distances
    '''
#     print('sdkfjsdkf')

    to_std = np.vstack((person, database))
    
    all_std = StandardScaler().fit_transform(to_std)
    person_std = all_std[0,:].reshape(1,-1)
    database_std = all_std[1:,:]
    
    if metric == 'euclidean':
        cont_distance_matrix = euclidean_distances(person_std, database_std)
        return cont_distance_matrix

# %%
def get_cat_dist(person, database, metric):
    '''
    Function that returns a distance matrix for categorical features of the data.
    I/P:
    'person': 1 x 3 numpy array of 1 person
    'database': (total data length) x 3 numpy array
    'metric': distance metric to be used for computation. One of: hamming
    
    O/P:
    'distance_matrix': 1 x (total data length) numpy array of distances
    '''
    cat_distance_matrix = []
    if metric == 'hamming':
        for index, c_row in database.iterrows():
            cat_distance_matrix.append(hamming(person, c_row))
    return(np.array(cat_distance_matrix))

# %%
get_cat_dist(test_cat, get_cont_cat(meta_data[meta_data['gender'] == 0], 'cat'), 'hamming')[57]
# Out:
# 0.0

# %%
get_cat_dist(test_cat, get_cont_cat(meta_data, 'cat'), 'hamming')
# Out:
# array([0.14814815, 0.2962963 , 0.22222222, 0.2962963 , 0.18518519,
#        0.22222222, 0.33333333, 0.22222222, 0.22222222, 0.25925926,
#        0.07407407, 0.14814815, 0.22222222, 0.33333333, 0.25925926,
#        0.25925926, 0.22222222, 0.33333333, 0.25925926, 0.18518519,
#        0.18518519, 0.25925926, 0.25925926, 0.22222222, 0.37037037,
#        0.25925926, 0.22222222, 0.33333333, 0.40740741, 0.2962963 ,
#        0.18518519, 0.18518519, 0.14814815, 0.25925926, 0.25925926,
#        0.18518519, 0.33333333, 0.18518519, 0.37037037, 0.18518519,
#        0.18518519, 0.25925926, 0.2962963 , 0.2962963 , 0.22222222,
#        0.25925926, 0.2962963 , 0.33333333, 0.40740741, 0.22222222,
#        0.2962963 , 0.2962963 , 0.2962963 , 0.25925926, 0.14814815,
#        0.25925926, 0.2962963 , 0.14814815, 0.18518519, 0.18518519,
#        0.14814815, 0.22222222, 0.2962963 , 0.22222222, 0.25925926,
#        0.2962963 , 0.33333333, 0.2962963 , 0.25925926, 0.48148148,
#        0.33333333, 0.22222222, 0.22222222, 0.25925926, 0.22222222,
#        0.25925926, 0.37037037, 0.25925926, 0.40740741, 0.2962963 ,
#        0.25925926, 0.2962963 , 0.22222222, 0.22222222, 0.37037037,
#        0.33333333, 0.25925926, 0.33333333, 0.25925926, 0.2962963 ,
#        0.37037037, 0.33333333, 0.18518519, 0.22222222, 0.2962963 ,
#        0.18518519, 0.2962963 , 0.14814815, 0.25925926, 0.22222222,
#        0.18518519, 0.14814815, 0.25925926, 0.18518519, 0.22222222,
#        0.25925926, 0.25925926, 0.18518519, 0.22222222, 0.25925926,
#        0.37037037, 0.37037037, 0.2962963 , 0.37037037, 0.14814815,
#        0.22222222, 0.25925926, 0.2962963 , 0.2962963 , 0.25925926,
#        0.22222222, 0.33333333])

# %%
test_cat = get_cont_cat(test_person, 'cat')
test_cat2 = get_cont_cat(meta_data.iloc[[34]], 'cat')

# %%
hamming(test_cat, test_cat2)
# Out:
# 0.25925925925925924

# %%
def findRoommate(new_person, database, n_roommates, alpha, beta):
    # Split data by gender to reduce computations
    database_g = database[database['gender'] == new_person.iloc[0]['gender']]
#     print(len(database_g))
    name_g = [name_list[i] for i in list(database_g.index)]
#     print(name_g)

    # Split new datapoint into continuous and categorical sets
    new_person_cont = get_cont_cat(new_person, 'cont')
    new_person_cat = get_cont_cat(new_person, 'cat')
    
#     print(new_person_cat.shape, new_person_cont.shape)
    
    # Split database into continuous and categorical sets
    database_cont = get_cont_cat(database_g, 'cont')
    database_cat = get_cont_cat(database_g, 'cat')
    
#     print(database_cat.shape, database_cont.shape)
    
    
    # Get distances for both continuous and categorical sets
    dist_cont = get_cont_dist(new_person_cont, database_cont, 'euclidean')
#     print(dist_cont.shape, np.argsort(dist_cont))
    
    

    dist_cat = get_cat_dist(new_person_cat, database_cat, 'hamming')
    
#     print(dist_cont + dist_cat)
    # Create final distance matrix of weighted average
    # Have to experiment with different alpha(cont_coeff) and beta(cat_coeff)
    # We good till here
    final_dist = alpha*dist_cont + beta*dist_cat
#     print(final_dist)
    # Sort the distance matrix to get top n roommates
    top_n_matches = np.argsort(final_dist)[0][1 : n_roommates + 1]
    print(top_n_matches)
    print(list(name_g[j] for j in top_n_matches))

# %%
findRoommate(test_person, meta_data, 10, 1, 1)
# Out:
# [215 311 357 178 186 115 113 192 142  75]
# ['Akash Piyush Parikh', 'Vivin Thomas Wilson', 'Gaurav Tripathi', 'Shreyansh Singh', 'Anshit Srivastava', 'Shashwat Shetty', 'Kousthubh B S', 'Ojas Phansekar', 'Adwait Joshi', 'Chirag shivnani']

# %%
name_list[[0,1,2]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-225-bd994382520f> in <module>()
# ----> 1 name_list[[0,1,2]]
#
# TypeError: list indices must be integers or slices, not list

# %%
test_person.iloc[0]['gender']
# Out:
# 0.0

# %%
0 == 0.0
# Out:
# True

# %%
meta_data.shape
# Out:
# (522, 30)

# %%
meta_data.gender.value_counts()
# Out:
# 0    401
# 1    121
# Name: gender, dtype: int64
