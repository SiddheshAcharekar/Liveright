# %%
import numpy as np
import pandas as pd

# %%
budd = pd.read_excel('../Data/find_my_buddy.csv.xlsx', sheet_name='Buddy Sheet')

# %%
budd
# Out:
#                                    Full Name                   Email address  \
# 0                        Sachin Haldavanekar    sachinhaldavanekar@gmail.com
# 1                              Sanket Saurav               snkt087@gmail.com
# 2                                 Viha Bidre             bidreviha@yahoo.com
# 3                            Sougata Dafader        sougatadafader@gmail.com
# 4                         Athul Muralidharan           athulmurali@gmail.com
# 5                             Megha Suvarna          megha.suvarna@ymail.com
# 6                                     Vishnu            kmvishnu92@gmail.com
# 7                           Srashti Kasliwal      srashti.kasliwal@gmail.com
# 8                                Balakumaran      balakumaran26694@gmail.com
# 9                                     Pranav          ppranavtembe@gmail.com
# 10                      Harshil Navin Dhruve       harshildhruve56@gmail.com
# ...
